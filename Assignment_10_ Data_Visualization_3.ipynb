# %% [markdown]
# #  1] Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 2] Loading dataset into pandas dataframe

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
cols=df.columns

# %%
cols
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# #  2. Create a histogram for each feature in the dataset to illustrate the feature distributions.

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
index=1
plt.figure(figsize=(25,20))
for col in cols[:-1]:
    plt.subplot(2,2,index)
    index=index+1
    sns.histplot(x=df[col],)

# %% [markdown]
# # 3. Create a box plot for each feature in the dataset.

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
index=1
plt.figure(figsize=(10,10))
for col in cols[:-1]:
    plt.subplot(2,2,index)
    index=index+1
    sns.boxplot(x=df[col])

# %% [markdown]
# # following things can be concluded:
#     1.Sepal width has less variations.
#     2.petal length has less variations.
#     3.sepal length size is large as compared to other measures in all species.
#     4.petal width size is small as compared to other measures in all species.
